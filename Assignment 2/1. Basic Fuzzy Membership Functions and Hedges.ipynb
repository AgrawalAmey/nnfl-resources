# %% [markdown]
# # Some Basic Fuzzy Mambership Functions and Hedges

# %%
import sys
import math
from operator import itemgetter
from functools import partial

# %% [markdown]
# # 1. Membership Functions

# %% [markdown]
# # 1a. Up Membership Function

# %% [markdown]
#
# mu(x,a,b) =
#      \begin{cases}
#        \text{0} &\quad\text{if x}\le a, \\
#        \dfrac{x-a}{b-a} &\quad\text{if x}\ge a \text{ and x}\le b,\\
#        \text{1} &\quad\text{otherwise.} \\
#      \end{cases}

# %%
from IPython.core.display import Image
Image(filename=('images/up.png'))

# %%
# a,b -> as defined above
# x -> point for which the membership value is to be obtained
# return the correct membership value
def up(a, b, x):
    # Your code here
 raise NotImplementedError()
 return 1.0

# %%
test1=up(1,2,0.5)
assert test1==0
test2=up(1,2,1.5)
assert test2==0.5
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-2-2bdb320696e5> in <module>()
# ----> 1 test1=up(1,2,0.5)
#       2 assert test1==0
#       3 test2=up(1,2,1.5)
#       4 assert test2==0.5
#
# <ipython-input-1-b9f9ca9b9c2c> in up(a, b, x)
#       4 def up(a, b, x):
#       5     # Your code here
# ----> 6  raise NotImplementedError()
#       7  return 1.0
#
# NotImplementedError:

# %% [markdown]
# # 1b. Triangular Membership Function

# %% [markdown]
# mu(x,a,b,m) =
#      \begin{cases}
#        \text{0} &\quad\text{if x}\le a, \\
#        \dfrac{x-a}{m-a} &\quad\text{if x}\ge a \text{ and x}\le m,\\
#        \dfrac{b-x}{b-m} &\quad\text{if x}\ge m \text{ and x}\le b,\\
#        \text{0} &\quad\text{otherwise.} \\
#      \end{cases}
#
#                   where m = (a+b)/2

# %%
from IPython.core.display import Image
Image(filename=('images/tri.png'))

# %%
# a,b,m -> as defined above
# x -> point for which the membership value is to be obtained
# return the correct membership value
def tri(a, b, x):
    #Your code here
    raise NotImplementedError()

# %%
test1=tri(1,2,0.5)
assert test1==0
test2=tri(1,2,1.5)
assert test2==1.0

# %% [markdown]
# mu(x,a,b,c, d) =
#      \begin{cases}
#        \text{0} &\quad\text{if x}\le a, \\
#        \dfrac{x-a}{b-a} &\quad\text{if x}\ge a \text{ and x}\le b,\\
#         \text{1} &\quad\text{if x}\ge b \text{ and x}\le c,\\
#        \dfrac{d-x}{d-c} &\quad\text{if x}\ge c \text{ and x}\le d,\\
#        \text{0} &\quad\text{otherwise.} \\
#      \end{cases}

# %%
from IPython.core.display import Image
Image(filename=('images/trap.png'))

# %%
# a,b,c,d -> as defined above
# x -> point for which the membershi value is to be obtained
# return the correct membership value
def trap(a, b, c, d, x):
    #Your code here
    raise NotImplementedError()

# %%
test1=trap(1,2,3,5,2.5)
assert test1==1.0
test2=trapp(1,2,3,5,4)
assert test2==0.5

# %% [markdown]
# # 2. Hedges

# %%
from IPython.core.display import Image
Image(filename=('images/Hedges1.png'))

# %%
# hedges
#raise mvalue to the power of p
def hedge(mvalue, p):
    """Generic definition of a function that alters a given membership function
    by intensifying it in the case of *very* of diluting it in the case of
    *somewhat*.  """

    #Your code here
    raise NotImplementedError()

# %%
mvalue=0.3
very = hedge(mvalue, 2.)
assert very==0.09
extremely = hedge(mvalue, 3.)
assert extremely==0.026999999999999996
somewhat = hedge(mvalue, 0.5)
assert somewhat==0.5477225575051661
slightly = hedge(mvalue, 1. / 3.)
assert slightly==0.6694329500821695
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-7-40723acd68a0> in <module>()
#       1 mvalue=0.3
# ----> 2 very = hedge(mvalue, 2.)
#       3 assert very==0.09
#       4 extermely = hedge(mvalue, 3.)
#       5 assert extremely==0.026999999999999996
#
# <ipython-input-5-1a241e94ec91> in hedge(p, mvalue)
#       7
#       8     #Your code here
# ----> 9     raise NotImplementedError()
#
# NotImplementedError:
